# %% [markdown]
# # Part 1

# %%
import networkx as nx

# %%
G = nx.read_gml(path=".\IUT-Graph-Mining-Course\Data Sets\Basic\Zachary's karate club\karate.gml")
# Out:
# <bound method Graph.number_of_nodes of <networkx.classes.graph.Graph object at 0x000001D77D04DD00>>
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\ahl\AppData\Local\Temp\ipykernel_18356\3392021727.py:1: SyntaxWarning: invalid escape sequence '\I'
#   G = nx.read_gml(path=".\IUT-Graph-Mining-Course\Data Sets\Basic\Zachary's karate club\karate.gml", destringizer=int)

# %%
# Out:
# 34
